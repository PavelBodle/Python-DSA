# %% [markdown]
# <a href="https://colab.research.google.com/github/PavelBodle/Python-DSA/blob/main/Pandas_Numpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Numpy

# %%
import numpy as np

# %%
a = range(10000)
a
# Out:
# range(0, 10000)

# %%
# %timeit b = [i**3 for i in a]
# Out:
# 1.11 ms ± 288 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
c_numpy = np.arange(10000)
# %timeit c_numpy**3
# Out:
# 48.4 µs ± 13.3 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
np.random.random([100,2])
# Out:
# array([[0.10202623, 0.69383533],
#        [0.1578003 , 0.27180549],
#        [0.96961592, 0.75703611],
#        [0.98234107, 0.20221792],
#        [0.33210732, 0.21065114],
#        [0.49352812, 0.3353459 ],
#        [0.00184848, 0.6872899 ],
#        [0.9553728 , 0.32872283],
#        [0.38812478, 0.13024851],
#        [0.09433853, 0.34280511],
#        [0.55231502, 0.72311946],
#        [0.14877715, 0.58033002],
#        [0.94278671, 0.9760045 ],
#        [0.07376151, 0.7938479 ],
#        [0.27292236, 0.61404087],
#        [0.00910485, 0.89135197],
#        [0.38474999, 0.3401173 ],
#        [0.18124615, 0.55813392],
#        [0.67134493, 0.17647336],
#        [0.54952885, 0.08779716],
#        [0.36630398, 0.73794742],
#        [0.33144377, 0.05395637],
#        [0.59216789, 0.92231797],
#        [0.52055201, 0.70706244],
#        [0.1072399 , 0.36280774],
#        [0.78260313, 0.67251746],
#        [0.99360365, 0.36570717],
#        [0.65796327, 0.65372189],
# ...
