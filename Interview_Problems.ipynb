# %% [markdown]
# <a href="https://colab.research.google.com/github/PavelBodle/Python-DSA/blob/main/Interview_Problems.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Stock Buy and Sell (Best Time to Buy and Sell Stock)
#
# > https://leetcode.com/problems/best-time-to-buy-and-sell-stock/description/

# %%
prices = [100, 180, 260, 310, 40, 535, 695]

def maxProfit(prices):

  res = 0

  for i in range(len(prices) - 1): ## loop to iterate only up to len(prices) - 1, preventing i+1 from going out of bounds.
    if prices[i+1] > prices[i]:
      res += prices[i+1] - prices[i]
  return res


maxProfit(prices)
# Out:
# 865
